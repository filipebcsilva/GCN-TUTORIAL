# %%
import numpy as np 

mat = np.random.random(size=(100, 100))
mat
# Out:
# array([[0.82124059, 0.12419092, 0.83633573, ..., 0.19973196, 0.64996706,
#         0.41279366],
#        [0.84196719, 0.55464023, 0.97671234, ..., 0.71460334, 0.38011139,
#         0.36923284],
#        [0.65718635, 0.78380065, 0.09217587, ..., 0.18121508, 0.86869934,
#         0.17613201],
#        ...,
#        [0.68936214, 0.12734776, 0.36849437, ..., 0.01288514, 0.70632162,
#         0.24030507],
#        [0.69017451, 0.77171958, 0.92343059, ..., 0.25846429, 0.46006193,
#         0.17764142],
#        [0.8957123 , 0.6106542 , 0.91875785, ..., 0.82819805, 0.45138223,
#         0.80873446]], shape=(100, 100))

# %%
v1 = np.random.random(size=(100, 4))
v2 = np.random.random(size=(4, 100))

mat = v1 @ v2
mat
# Out:
# array([[1.62529916, 2.16709782, 1.32270789, ..., 1.34413144, 1.83960141,
#         1.1076076 ],
#        [0.7621469 , 1.06261222, 0.90209755, ..., 0.93980382, 0.70053421,
#         0.86958917],
#        [0.8338325 , 1.21600731, 0.94398571, ..., 0.9443205 , 0.85050152,
#         0.86478057],
#        ...,
#        [0.88419973, 1.45381981, 0.80730737, ..., 0.78493553, 1.19111459,
#         0.55148589],
#        [0.8079118 , 1.2370122 , 0.71691398, ..., 0.62509844, 1.02961033,
#         0.54464469],
#        [1.09832943, 1.50740375, 0.96444733, ..., 0.94342697, 1.23624791,
#         0.82250354]], shape=(100, 100))
